# %% [markdown]
# <a href="https://colab.research.google.com/github/sreelakshmi1405/Internship/blob/main/EDA_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA- Iris Dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#display first 5 rows
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# %%
type(iris_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
iris_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
#features name
iris_data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
#dependent variables
iris_data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_data['data']
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
iris_df = pd.DataFrame(iris_data['data'], columns=iris_data['feature_names'])
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df['Iris type'] = iris_data['target']
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Iris type
# 0            0
# ...

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Iris type
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
print(f"Dataset shape: {iris.shape}")
# Out:
# Dataset shape: (150, 5)

# %%
#basic information
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#statistical summary
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#check for missing values
print(iris.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#dataset duplicate value count
dup = iris_df.duplicated().sum()
print(dup)
# Out:
# 1

# %%
iris_df['Iris type'].value_counts()
# Out:
# Iris type
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#Categorical Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

iris_df['Encoded_Species'] = le.fit_transform(iris_df['Iris type'])

unique_species = iris_df['Encoded_Species'].unique()

print("Encoded Species Values:")
print(unique_species)
# Out:
# Encoded Species Values:
# [0 1 2]

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Iris type  Encoded_Species
# ...

# %%
print("\nSpecies Distribution:")
print(iris['species'].value_counts())
# Out:
# Species Distribution:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# Distribution of Numerical Features

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

sns.histplot(iris_df['sepal length (cm)'], kde=True, ax=axes[0, 0], color='green')
axes[0, 0].set_title('Distribution of Sepal Length')

sns.histplot(iris_df['sepal width (cm)'], kde=True, ax=axes[0, 1], color='blue')
axes[0, 1].set_title('Distribution of Sepal Width')

sns.histplot(iris_df['petal length (cm)'], kde=True, ax=axes[1, 0], color='orange')
axes[1, 0].set_title('Distribution of Petal Length')

sns.histplot(iris_df['petal width (cm)'], kde=True, ax=axes[1, 1], color='red')
axes[1, 1].set_title('Distribution of Petal Width')

plt.tight_layout()
plt.show()

# %% [markdown]
# Boxplots for Numerical featues

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = iris_df.drop(columns=['Iris type', 'Encoded_Species']))
plt.title('Boxplot of all numerical features')
plt.ylabel('Centimeter(cm)')
plt.show()

# %%
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 15})
plt.rcParams['font.family']='sans-serif'
sns.set_style('darkgrid')

# %%
sns.countplot(x=iris_df['Iris type'].replace(dict(enumerate(iris_data['target_names']))), data=iris_df)
plt.title('Species Distribution')
plt.xlabel('Species Type')
plt.ylabel('Count')
plt.show()

# %%
iris_df['Iris type'].replace(dict(enumerate(iris_data['target_names']))).value_counts().plot.pie(explode=[0.1,0.1,0.1], autopct='%1.1f%%', shadow= True, figsize=(10,8))
plt.ylabel('') # Remove the default 'Iris type' label from the y-axis
plt.title('Distribution of Iris Species')
plt.show()

# %%
iris_df.hist(edgecolor='black', figsize=(12,12))
plt.show()

# %%
# Chart - 1 Histogram visualization code for distribution of numerical variables
# Create a figure with subplots

plt.figure(figsize=(8, 6))
plt.suptitle('Distribution of Iris Flower Measurements', fontsize=14)

# Create a 2x2 grid of subplots

plt.subplot(2, 2, 1)  # Subplot 1 (Top-Left)
plt.hist(df['SepalLengthCm'])
plt.title('Sepal Length Distribution')

plt.subplot(2, 2, 2)  # Subplot 2 (Top-Right)
plt.hist(df['SepalWidthCm'])
plt.title('Sepal Width Distribution')

plt.subplot(2, 2, 3)  # Subplot 3 (Bottom-Left)
plt.hist(df['PetalLengthCm'])
plt.title('Petal Length Distribution')

plt.subplot(2, 2, 4)  # Subplot 4 (Bottom-Right)
plt.hist(df['PetalWidthCm'])
plt.title('Petal Width Distribution')

# Display the subplots
plt.tight_layout()  # Helps in adjusting the layout
plt.show()

# %%
sns.boxplot(x="Species", y="PetalLengthCm", data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=df)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=df, jitter=True, edgecolor="gray")
# Out:
# /tmp/ipykernel_677/3542948724.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x="Species", y="PetalLengthCm", data=df, jitter=True, edgecolor="gray")

# %% [markdown]
# Bivariate Analysis

# %%
# Create the figure
plt.figure(figsize=(8, 6))
species = df['Species'].unique()
colors = ['red', 'green', 'blue']

# Scatter plot for each species
for i in range(len(species)):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c=colors[i], label=species[i])

# Add labels and legend
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Width by Species')
plt.legend()

plt.show()

# %%
df.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
#pairwise relationship
sns.pairplot(df , hue='Species');

# %%
sns.pairplot(df , hue='SepalWidthCm');

# %%
sns.pairplot(iris, hue='species', palette='viridis', height=2.5)
plt.suptitle('Pairwise Relationships by Species', y=1.02)
plt.show()

# %%
# Calculate correlation
corr = iris.drop('species', axis=1).corr()
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
df.drop(columns=['Species']).corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
df.iloc[:, :-1].corr().style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_aaf41_row0_col0, #T_aaf41_row1_col1, #T_aaf41_row2_col2, #T_aaf41_row3_col3, #T_aaf41_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aaf41_row0_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_aaf41_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_aaf41_row0_col3, #T_aaf41_row3_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_aaf41_row0_col4, #T_aaf41_row4_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_aaf41_row1_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_aaf41_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_aaf41_row1_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_aaf41_row1_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_aaf41_row2_col0, #T_aaf41_row2_col1, #T_aaf41_row2_col3, #T_aaf41_row2_col4, #T_aaf41_row3_col2 {
#   background-color: #3b4cc0;
# ...

# %% [markdown]
# Multivariate Analysis

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# Plot distributions by species
sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0], palette='Set2')
axes[0, 0].set_title('Sepal Length by Species')
sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1], palette='Set2')
axes[0, 1].set_title('Sepal Width by Species')
sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0], palette='Set2')
axes[1, 0].set_title('Petal Length by Species')
sns.boxplot(x='species', y='petal_width', data=iris, ax=axes[1, 1], palette='Set2')
axes[1, 1].set_title('Petal Width by Species')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_677/4165190797.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0], palette='Set2')
# /tmp/ipykernel_677/4165190797.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1], palette='Set2')
# /tmp/ipykernel_677/4165190797.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0], palette='Set2')
# /tmp/ipykernel_677/4165190797.py:10: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile', palette='pastel')
plt.title('Petal Length Distribution by Species')
plt.show()
# Out:
# /tmp/ipykernel_677/3742048603.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile', palette='pastel')

# %% [markdown]
# Advanced Visualizations

# %%
from pandas.plotting import andrews_curves
plt.figure(figsize=(10, 6))
andrews_curves(iris, 'species', colormap='viridis')
plt.title('Andrews Curves for Iris Dataset')
plt.show()

# %%
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(10, 6))
parallel_coordinates(iris, 'species', colormap='viridis')
plt.title('Parallel Coordinates Plot for Iris Dataset')
plt.show()
